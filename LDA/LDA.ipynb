# %%
import os
import pandas as pd
import numpy as np
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly as py
import plotly.graph_objs as go
import gensim
from gensim import corpora, models, similarities
import logging
import tempfile
from nltk.corpus import stopwords
from string import punctuation
from collections import OrderedDict
import seaborn as sns
import pyLDAvis.gensim
import matplotlib.pyplot as plt
# %matplotlib inline

init_notebook_mode(connected=True) #do not miss this line

import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
datafile = 'data.csv'

# %%
import pandas as pd

tweets = pd.read_csv(datafile, sep = ";", error_bad_lines = False, encoding='latin1')

print("Number of tweets: ",len(tweets['text']))
tweets.head(5)
# Out:
# Number of tweets:  4225
#    ï»¿Column1    datetime        username  \
# 0           0  2020-05-01    himmoderator
# 1           1  2020-05-01    himmoderator
# 2           2  2020-05-01  Indorosstaylor
# 3           3  2020-05-01       epaphotos
# 4           4  2020-05-01       Tashtania
#
#                                          origin_text  \
# 0  Whatever happened to that  #Indonesia  governm...
# 1  Thank you  @febrofirdaus  for publishing this ...
# 2  Indonesian  villagers block  coronavirus  buri...
# 3  An  Indonesian  official wearing a robot costu...
# 4  "With global attention fixated on the  coronav...
#
#                                                 text  like  retweet  reply  \
# 0  whatever happened indonesia government promise...     1        1      0
# 1  thank febrofirdaus publishing piece shocking p...     2        4      0
# 2  indonesian villagers block coronavirus burials...     1        0      0
# 3  indonesian official wearing robot costume asks...     7        5      0
# 4  global attention fixated coronavirus pandemic ...     0        0      1
#
#    neg  neu  pos  compound sentiment
# 0    0  887  113      3182  Positive
# 1  112  785  103      -516  Negative
# 2  452  548    0      -765  Negative
# 3    0   10    0         0   Neutral
# 4    0   10    0         0   Neutral

# %% [markdown]
# ***Tweet Activity Over Years***

# %%
'''import plotly.plotly as py
import plotly.graph_objs as go
'''
tweets['datetime'] = pd.to_datetime(tweets['datetime'], format='%Y-%m-%d')
tweetsT = tweets['datetime']

trace = go.Histogram(
    x=tweetsT,
    marker=dict(
        color='blue'
    ),
    opacity=0.75
)

layout = go.Layout(
    title='Tweet Activity in May',
    height=450,
    width=1200,
    xaxis=dict(
        title='Date and Month'
    ),
    yaxis=dict(
        title='Tweet Quantity'
    ),
    bargap=0.2,
)

data = [trace]

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="93512b61-5c08-41a9-8ada-14ba8e260e5b" class="plotly-graph-div" style="height:450px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93512b61-5c08-41a9-8ada-14ba8e260e5b")) {
#                     Plotly.newPlot(
#                         '93512b61-5c08-41a9-8ada-14ba8e260e5b',
#                         [{"marker": {"color": "blue"}, "opacity": 0.75, "type": "histogram", "x": ["2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-01T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00:00:00", "2020-05-02T00 ...

# %%
# Preparing a corpus for analysis and checking first 10 entries

corpus=[]
a=[]
for i in range(len(tweets['text'])):
        a=tweets['text'][i]
        corpus.append(a)
        
corpus[0:10]
# Out:
# ['whatever happened indonesia government promise release 50000 detainees jails prisons covid19 coronavirus',
#  'thank febrofirdaus publishing piece shocking photo penjara salemba jakarta indonesia covid19 coronavirus jail',
#  'indonesian villagers block coronavirus burials fearing contamination via scmpnews',
#  'indonesian official wearing robot costume asks people stay home campaign amid covid19 coronavirus outbreak slum area bandung west java indonesia epaefe iqbal kusumadirezza epaphotos photojournalism indonesia westjava',
#  'global attention fixated coronavirus pandemic small indonesian central sulawesi city poso surrounding mountains seen concerning miniresurgence jihadi activity',
#  'media indonesia quoted bangli covid19 task force deputy chairman lieutenant colonel inf himawan teddy laksono saying decision made result transmission coronavirus one indonesian migrant worker 10 residents banjar serokadan neighb',
#  'goodbye april welcome may want corona virus could end fast indonesia around world aamiin',
#  'indonesian study low vitamin patients ten times likely die coronavirus  jonova via joannenova',
#  'indonesian president jokowi tells nation coronavirus pandemic exposed problems health security system medical facilities staff pharma equipment allowed us see potential resources yet managed developed well',
#  'excellent article sdjaffrey indonesia  coronavirus response  set back misplaced priorities distrust data gavincoote nadiasdaly laurentomasi carnegieendow indonesia timorleste dili covid19']

# %%
TEMP_FOLDER = tempfile.gettempdir()
print('Folder "{}" will be used to save temporary dictionary and corpus.'.format(TEMP_FOLDER))

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# Folder "C:\Users\yusuf\AppData\Local\Temp" will be used to save temporary dictionary and corpus.

# %%
import nltk
nltk.download('stopwords')

# removing common words and tokenizing
list1 = ['corona', 'coronavirus','indonesia', 'indonesian','covid19', 'covid', 'via',
         'city', 'names', 'may', 'today', 'new', 'could', 
         '24', '557', '678', '4', '20', '1520', '25773', '30', '10', '25216', '29', '1', '53', '28',
         'â€¦', 'â€¢', 'â€™', 'â€“', 'Â«', 'â€', 'Â»', 'â‚¬', 'Â£', 'Â©', 'Â°c', ' Â£', 'å', 'â', 'ë']
stoplist = stopwords.words('english') + list(punctuation) + list1

texts = [[word for word in str(document).lower().split() if word not in stoplist] for document in corpus]

dictionary = corpora.Dictionary(texts)
dictionary.save(os.path.join(TEMP_FOLDER, 'elon.dict'))  # store the dictionary, for future reference

#print(dictionary)
#print(dictionary.token2id)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yusuf\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2020-06-23 11:02:30,779 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-06-23 11:02:30,921 : INFO : built Dictionary(9746 unique tokens: ['50000', 'detainees', 'government', 'happened', 'jails']...) from 4225 documents (total 56936 corpus positions)
# 2020-06-23 11:02:30,922 : INFO : saving Dictionary object under C:\Users\yusuf\AppData\Local\Temp\elon.dict, separately None
# 2020-06-23 11:02:30,927 : INFO : saved C:\Users\yusuf\AppData\Local\Temp\elon.dict

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
corpora.MmCorpus.serialize(os.path.join(TEMP_FOLDER, 'elon.mm'), corpus)  # store to disk, for later use
# Out:
# 2020-06-23 11:02:31,023 : INFO : storing corpus in Matrix Market format to C:\Users\yusuf\AppData\Local\Temp\elon.mm
# 2020-06-23 11:02:31,025 : INFO : saving sparse matrix to C:\Users\yusuf\AppData\Local\Temp\elon.mm
# 2020-06-23 11:02:31,026 : INFO : PROGRESS: saving document #0
# 2020-06-23 11:02:31,056 : INFO : PROGRESS: saving document #1000
# 2020-06-23 11:02:31,083 : INFO : PROGRESS: saving document #2000
# 2020-06-23 11:02:31,108 : INFO : PROGRESS: saving document #3000
# 2020-06-23 11:02:31,134 : INFO : PROGRESS: saving document #4000
# 2020-06-23 11:02:31,140 : INFO : saved 4225x9746 matrix, density=0.132% (54414/41176850)
# 2020-06-23 11:02:31,142 : INFO : saving MmCorpus index to C:\Users\yusuf\AppData\Local\Temp\elon.mm.index

# %% [markdown]
# In the previous cells, I created a corpus of documents represented as a stream of vectors. To continue, lets use that corpus, with the help of Gensim.

# %% [markdown]
# ### Creating a transformation

# %% [markdown]
# The transformations are standard Python objects, typically initialized by means of a training corpus:
#
# Different transformations may require different initialization parameters; in case of TfIdf, the “training” consists simply of
# going through the supplied corpus once and computing document frequencies of all its features.
# Training other models, such as Latent Semantic Analysis or Latent Dirichlet Allocation, is much more involved and,
# consequently, takes much more time.

# %%
tfidf = models.TfidfModel(corpus) # step 1 -- initialize a model
# Out:
# 2020-06-23 11:02:31,153 : INFO : collecting document frequencies
# 2020-06-23 11:02:31,154 : INFO : PROGRESS: processing document #0
# 2020-06-23 11:02:31,172 : INFO : calculating IDF weights for 4225 documents and 9746 features (54414 matrix non-zeros)

# %% [markdown]
# ### Note
# Transformations always convert between two specific vector spaces. The same vector space (= the same set of feature ids) must be used for training as well as for subsequent vector transformations. Failure to use the same input feature space, such as applying a different string preprocessing, using different feature ids, or using bag-of-words input vectors where TfIdf vectors are expected, will result in feature mismatch during transformation calls and consequently in either garbage output and/or runtime exceptions.

# %% [markdown]
# From now on, tfidf is treated as a read-only object that can be used to apply a transformation to a whole corpus:

# %%
corpus_tfidf = tfidf[corpus]  # step 2 -- use the model to transform vectors

# %% [markdown]
# ### LDA:
# https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation

# %% [markdown]
# Latent Dirichlet Allocation, LDA is yet another transformation from bag-of-words counts into a topic space of lower dimensionality. LDA is a probabilistic extension of LSA (also called multinomial PCA), so LDA’s topics can be interpreted as probability distributions over words. These distributions are, just like with LSA, inferred automatically from a training corpus. Documents are in turn interpreted as a (soft) mixture of these topics (again, just like with LSA).

# %%
total_topics = 5

# %%
lda = models.LdaModel(corpus, id2word=dictionary, num_topics=total_topics)
corpus_lda = lda[corpus_tfidf] # create a double wrapper over the original corpus: bow->tfidf->fold-in-lsi
# Out:
# 2020-06-23 11:02:32,736 : INFO : using symmetric alpha at 0.2
# 2020-06-23 11:02:32,737 : INFO : using symmetric eta at 0.2
# 2020-06-23 11:02:32,741 : INFO : using serial LDA version on this node
# 2020-06-23 11:02:32,747 : INFO : running online (single-pass) LDA training, 5 topics, 1 passes over the supplied corpus of 4225 documents, updating model once every 2000 documents, evaluating perplexity every 4225 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-06-23 11:02:32,748 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2020-06-23 11:02:32,749 : INFO : PROGRESS: pass 0, at document #2000/4225
# 2020-06-23 11:02:34,237 : INFO : merging changes from 2000 documents into a model of 4225 documents
# 2020-06-23 11:02:34,243 : INFO : topic #0 (0.200): 0.038*"cases" + 0.025*"deaths" + 0.010*"total" + 0.009*"malaysia" + 0.008*"philippines" + 0.007*"reports" + 0.007*"recovered" + 0.007*"singapore" + 0.007*"thailand" + 0.006*"0"
# 2020-06-23 11:02:34,245 : INFO : topic #1 (0.200): 0.025*"cases" + 0.014*"infections" + 0.014*"reports" + 0.013*"deaths" + 0.013*"total" + 0.009*"pandemic" + 0.009*"daily" + 0.008*"rise" + 0.008*"malaysia" + 0.008*"singapore"
# 2020-06-23 11:02:34,247 : INFO : topic #2 (0.200): 0.035*"cases" + 0.009*"deaths" + 0.007*"update" + 0.007*"virus" + 0.006*"tot" + 0.006*"recovered" + 0.006*"health" + 0.006*"total" + 0.005*"china" + 0.005*"market"
# 2020-06-23 11:02:34,250 : INFO : topic #3 (0.200): 0.016*"cases" + 0.012*"deaths" + 0.011*"virus" + 0.008*"death" + 0.007*"reports" + 0.007*"amid" + 0.006*"markets" + 0.006*"tot" + 0.005*"china" + 0.005*"people"
# 2020-06-23 11:02:34,252 : INFO : topic #4 (0.200): 0.011*"deaths" + 0.010*"cases" + 0.008*"reports" + 0.007*"animals" + 0.007*"far" + 0.007*"pandemic" + 0.006*"superheroes" + 0.006*"near" + 0.006*"battle" + 0.006*"starvation"
# 2020-06-23 11:02:34,253 : INFO : topic diff=3.972187, rho=1.000000
# 2020-06-23 11:02:34,254 : INFO : PROGRESS: pass 0, at document #4000/4225
# 2020-06-23 11:02:35,203 : INFO : merging changes from 2000 documents into a model of 4225 documents
# 2020-06-23 11:02:35,207 : INFO : topic #0 (0.200): 0.036*"cases" + 0.024*"deaths" + 0.011*"reports" + 0.009*"total" + 0.009*"fight" + 0.009*"late" + 0.007*"crash" + 0.007*"plane" + 0.007*"dies" + 0.006*"american"
# 2020-06-23 11:02:35,208 : INFO : topic #1 (0.200): 0.034*"cases" + 0.026*"reports" + 0.021*"deaths" + 0.019*"infections" + 0.016*"total" + 0.014*"daily" + 0.009*"biggest" + 0.008*"pandemic" + 0.007*"rise" + 0.006*"malaysia"
# 2020-06-23 11:02:35,209 : INFO : topic #2 (0.200): 0.023*"cases" + 0.008*"data" + 0.008*"virus" + 0.008*"tot" + 0.007*"army" + 0.007*"patients" + 0.007*"update" + 0.007*"health" + 0.007*"pandemic" + 0.006*"deaths"
# 2020-06-23 11:02:35,211 : INFO : topic #3 (0.200): 0.015*"virus" + 0.012*"cases" + 0.009*"death" + 0.007*"deaths" + 0.006*"amid" + 0.006*"markets" + 0.006*"â" + 0.006*"like" + 0.005*"å" + 0.005*"tot"
# 2020-06-23 11:02:35,213 : INFO : topic #4 (0.200): 0.012*"pandemic" + 0.005*"deaths" + 0.005*"cases" + 0.005*"2020" + 0.005*"plans" + 0.005*"government" + 0.004*"billion" + 0.004*"reports" + 0.004*"bailout" + 0.004*"asia"
# 2020-06-23 11:02:35,214 : INFO : topic diff=1.144116, rho=0.707107
# 2020-06-23 11:02:35,325 : INFO : -9.304 per-word bound, 632.3 perplexity estimate based on a held-out corpus of 225 documents with 2722 words
# 2020-06-23 11:02:35,326 : INFO : PROGRESS: pass 0, at document #4225/4225
# 2020-06-23 11:02:35,413 : INFO : merging changes from 225 documents into a model of 4225 documents
# 2020-06-23 11:02:35,417 : INFO : topic #0 (0.200): 0.032*"late" + 0.031*"cases" + 0.029*"sprawling" + 0.028*"surges" + 0.025*"deaths" + 0.011*"death" + 0.008*"crash" + 0.008*"fight" + 0.008*"world" + 0.007*"riots"
# 2020-06-23 11:02:35,418 : INFO : topic #1 (0.200): 0.038*"cases" + 0.034*"reports" + 0.025*"infections" + 0.025*"deaths" + 0.014*"total" + 0.011*"daily" + 0.008*"rise" + 0.008*"reported" + 0.008*"health" + 0.007*"malaysia"
# 2020-06-23 11:02:35,420 : INFO : topic #2 (0.200): 0.026*"minister" + 0.018*"wife" + 0.017*"cases" + 0.014*"tot" + 0.013*"like" + 0.008*"virus" + 0.008*"india" + 0.007*"patients" + 0.007*"china" + 0.006*"update"
# 2020-06-23 11:02:35,421 : INFO : topic #3 (0.200): 0.018*"virus" + 0.012*"death" + 0.010*"fire" + 0.010*"like" + 0.007*"cases" + 0.006*"amid" + 0.006*"floods" + 0.006*"â" + 0.006*"kobe" + 0.006*"å"
# 2020-06-23 11:02:35,423 : INFO : topic #4 (0.200): 0.019*"pandemic" + 0.009*"bali" + 0.008*"public" + 0.008*"2020" + 0.007*"violators" + 0.007*"one" + 0.007*"bryant" + 0.006*"compares" + 0.006*"shaming" + 0.006*"wife"
# 2020-06-23 11:02:35,424 : INFO : topic diff=0.674346, rho=0.577350

# %%
#Show first n important word in the topics:
lda.show_topics(total_topics,5)
# Out:
# [(0,
#   '0.032*"late" + 0.031*"cases" + 0.029*"sprawling" + 0.028*"surges" + 0.025*"deaths"'),
#  (1,
#   '0.038*"cases" + 0.034*"reports" + 0.025*"infections" + 0.025*"deaths" + 0.014*"total"'),
#  (2,
#   '0.026*"minister" + 0.018*"wife" + 0.017*"cases" + 0.014*"tot" + 0.013*"like"'),
#  (3,
#   '0.018*"virus" + 0.012*"death" + 0.010*"fire" + 0.010*"like" + 0.007*"cases"'),
#  (4,
#   '0.019*"pandemic" + 0.009*"bali" + 0.008*"public" + 0.008*"2020" + 0.007*"violators"')]

# %%
data_lda = {i: OrderedDict(lda.show_topic(i,25)) for i in range(total_topics)}
#data_lda

# %%
df_lda = pd.DataFrame(data_lda)
df_lda = df_lda.fillna(0).T
print(df_lda.shape)
# Out:
# (5, 94)

# %%
df_lda
# Out:
#        late     cases  sprawling    surges    deaths     death     crash  \
# 0  0.031824  0.030701   0.029366  0.028429  0.024716  0.011066  0.008367
# 1  0.000000  0.038180   0.000000  0.000000  0.024980  0.000000  0.000000
# 2  0.000000  0.017054   0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.006976   0.000000  0.000000  0.000000  0.012323  0.000000
# 4  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000  0.005436
#
#       fight     world     riots  ...  misogynistic     york     rolls  \
# 0  0.008051  0.007737  0.007194  ...      0.000000  0.00000  0.000000
# 1  0.000000  0.000000  0.000000  ...      0.000000  0.00000  0.000000
# 2  0.000000  0.000000  0.000000  ...      0.000000  0.00000  0.000000
# 3  0.000000  0.000000  0.000000  ...      0.000000  0.00000  0.000000
# 4  0.000000  0.000000  0.005379  ...      0.006218  0.00574  0.005495
#
#     giraffe  ministers   comment  devastating  jetliner    global  ukrainian
# 0  0.000000   0.000000  0.000000     0.000000  0.000000  0.000000   0.000000
# 1  0.000000   0.000000  0.000000     0.000000  0.000000  0.000000   0.000000
# 2  0.000000   0.000000  0.000000     0.000000  0.000000  0.000000   0.000000
# 3  0.000000   0.000000  0.000000     0.000000  0.000000  0.000000   0.000000
# 4  0.005428   0.005424  0.005358     0.005181  0.005126  0.005033   0.004976
#
# [5 rows x 94 columns]

# %%
g=sns.clustermap(df_lda.corr(), center=0, standard_scale=1, cmap="RdBu", metric='cosine', linewidths=.75, figsize=(15, 15))
plt.setp(g.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()
#plt.setp(ax_heatmap.get_yticklabels(), rotation=0)  # For y axis

# %%
pyLDAvis.enable_notebook()
panel = pyLDAvis.gensim.prepare(lda, corpus_lda, dictionary, mds='tsne')
panel
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 4      150.222153  -72.269554       1        1  53.409428
# 3       51.163364 -159.968018       2        1  16.185942
# 2      -73.144554   21.523815       3        1  10.202666
# 1      -66.410133 -110.606438       4        1  10.112175
# 0       54.417324   12.443444       5        1  10.089789, topic_info=            Term       Freq      Total Category  logprob  loglift
# 184        cases  47.000000  47.000000  Default  30.0000  30.0000
# 394      reports  25.000000  25.000000  Default  29.0000  29.0000
# 3274        late  13.000000  13.000000  Default  28.0000  28.0000
# 185       deaths  29.000000  29.000000  Default  27.0000  27.0000
# 9151   sprawling  15.000000  15.000000  Default  26.0000  26.0000
# ...          ...        ...        ...      ...      ...      ...
# 374         iran   1.793507  14.595963   Topic5  -5.4710   0.1971
# 621   australian   1.697815  14.488283   Topic5  -5.5258   0.1496
# 443     thailand   1.377123   5.207032   Topic5  -5.7351   0.9636
# 105        times   1.373883   9.741303   Topic5  -5.7375   0.3349
# 1532        kobe   1.373882  16.941166   Topic5  -5.7375  -0.2185
#
# [367 rows x 6 columns], token_table=      Topic      Freq  Term
# term
# 444       4  0.928212   103
# 8256      4  0.930291  1150
# 5285      1  0.868571  2016
# 302       1  0.627211  2020
# 302       2  0.147579  2020
# ...     ...       ...   ...
# 157       1  0.875052   zoo
# 157       2  0.097228   zoo
# 200       1  0.314387    â
# 200       2  0.628775    â
# 201       2  0.800365    å
#
# [434 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 4, 3, 2, 1])
